# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# This is for Goviral

# %%
# target = [0.788,0.705,0.678,0.688,0.691]
# lr = [0.686,0.688,0.462,0.462,0.677]
# fred = [0.6,0.77,0.743,0.615,0.672]
# fred_dem = [0.62,0.783,0.697,0.673,0.675]
# hier = [0.692,0.683,0.637,0.687,0.685]
# hier_dem = [0.702,0.672,0.737,0.716,0.71]



# target = [0.652,0.695,0.643,0.712]
target = [0.663,0.691,0.704,0.652,0.679,0.705]
#lr = [0.681,0.673,0.673,0.767]

lr = [0.669,0.677,0.683,0.681,0.68,0.688]
# fred = [0.675,0.703,0.714,0.68]
fred = [0.83,0.664,0.651,0.675,0.712,0.644]
fred_dem = [0.784,0.672,0.634,0.693,0.664,0.662]
hier = [0.66,0.702,0.709,0.641,0.71,0.676]
hier_dem = [0.666,0.671,0.664,0.71,0.69,0.68]


# fred_dem = [0.693,0.71,0.719,0.704]
# hier = [0.641,0.704,0.675,0.72]
# hier_dem = [0.71,0.712,0.672,0.741]

# target = [0.678,0.688,0.691]
# lr = [0.462,0.462,0.677]
# fred = [0.743,0.615,0.672]
# fred_dem = [0.697,0.673,0.675]
# hier = [0.637,0.687,0.685]
# hier_dem = [0.737,0.716,0.71]

x = np.arange(6)


plt.plot(x,target)
plt.plot(x,lr)
plt.plot(x,fred)
plt.plot(x,fred_dem)
plt.plot(x,hier)
plt.plot(x,hier_dem)
plt.title("Goviral")
# plt.xticks(np.arange(6), ('20', '40', '60', '80', '100'))
plt.xticks(np.arange(6), ( '5', '10','15' ,'20','25','30'))

plt.xlabel("Proportion of training instances")
plt.ylabel("AUC Scores")
plt.legend(['target','LR','FRED','FRED (demo)','Hier','Hier (demo)'],loc = 'upper right')
plt.show()

# %% [markdown]
# Fluwatch

# %%
# target = [0.563,0.629,0.616,0.623,0.57]
# lr = [0.471,0.511,0.5,0.674,0.46]
# fred = [0.388,0.45,0.483,0.657,0.521]
# fred_dem = [0.35,0.526,0.754,0.667,0.612]
# hier = [0.524,0.517,0.455,0.444,0.486]
# hier_dem = [0.617,0.625,0.692,0.628,0.627]


# target = [0.59,0.483,0.611,0.618]
# lr = [0.461,0.471,0.471,0.455]
# fred= [0.521,0.474,0.466,0.472]
# fred_dem =[0.612,0.756,0.718,0.722]
# hier = [0.599,0.501,0.499,0.505]
# hier_dem = [0.627,0.673,0.679,0.715]

target = [0.609,0.57,0.6,0.59 ,0.597,0.601]
lr = [0.466,0.46,0.461,0.461,0.482,0.474]
fred = [0.49,0.552,0.521,0.521,0.468,0.42]
fred_dem = [0.665,0.724,0.718,0.612,0.757,0.75]
hier = [0.503,0.453,0.452,0.599,0.6,0.5]
hier_dem = [0.565,0.576,0.699,0.627,0.71,0.679]





















# target = [0.616,0.623,0.57]
# lr = [0.5,0.674,0.46]
# fred = [0.483,0.657,0.521]
# fred_dem = [0.754,0.667,0.612]
# hier = [0.455,0.444,0.486]
# hier_dem = [0.692,0.628,0.627]

x = np.arange(6)


plt.plot(x,target)
plt.plot(x,lr)
plt.plot(x,fred)
plt.plot(x,fred_dem)
plt.plot(x,hier)
plt.plot(x,hier_dem)
plt.title("Fluwatch")
# plt.xticks(np.arange(3), ('20', '40', '60', '80', '100'))
plt.xticks(np.arange(6), ('5','10','15', '20','25','30'))

plt.xlabel("Proportion of training instances")
plt.ylabel("AUC Scores")
plt.legend(['target','LR','FRED','FRED (demo)','Hier','Hier (demo)'],loc = 'lower right')
plt.show()

# %% [markdown]
# Hongkong

# %%
# target = [0.866,0.863,0.88,0.885,0.9]
# lr = [0.858,0.856,0.499,0.446,0.883]
# fred = [0.808,0.921,0.817,0.89,0.9]
# fred_dem = [0.85,0.918,0.91,0.9,0.91]
# hier = [0.85,0.874,0.884,0.887,0.889]
# hier_dem = [0.907,0.904,0.918]
# target = [0.88,0.885,0.9]
# lr = [0.499,0.446,0.883]
# fred = [0.817,0.89,0.9]
# fred_dem = [0.91,0.9,0.91]
# hier = [0.884,0.887,0.889]
# hier_dem = [0.907,0.904,0.918]


target =[0.89,0.885,0.905,0.91]
lr = [0.882,0.887,0.887,0.888]
fred= [0.9,0.9,0.897,0.897]
fred_dem = [0.914,0.968,0.971,0.985]
hier = [0.902,0.888,0.89,0.903]
hier_dem = [0.918,0.923,0.928,0.938]


target = [0.889,0.9,0.902,0.89,0.901,0.9]
lr = [0.88,0.883,0.882,0.882,0.884,0.883]
fred = [0.92,0.905,0.899,0.9,0.896,0.972]
fred_dem = [0.956,0.896,0.971,0.914,0.969,0.97]
hier = [0.887,0.889,0.889,0.902,0.95,0.889]
hier_dem = [0.894,0.911,0.984,0.918,0.94,0.917]


x = np.arange(6)


plt.plot(x,target)
plt.plot(x,lr)
plt.plot(x,fred)
plt.plot(x,fred_dem)
plt.plot(x,hier)
plt.plot(x,hier_dem)
plt.title("Hongkong")
plt.xticks(np.arange(6), ('5','10','15', '20','25','30'))
plt.xlabel("Proportion of training instances")
plt.ylabel("AUC Scores")
plt.legend(['target','LR','FRED','FRED (demo)','Hier','Hier (demo)'],loc = 'lower right')
plt.show()

# %% [markdown]
# Hutterite

# %%
# target = [0.616,0.726,0.5,0.709,0.707]
# lr = [0.528,0.75,0.506,0.746,0.744]
# fred = [0.684,0.788,0.757,0.714,0.726]
# fred_dem = [0.625,0.722,0.894,0.72,0.824]
# hier = [0.71,0.707,0.693,0.691,0.719]
# hier_dem = [0.796,0.771,0.829,0.785,0.827]


# target = [0.5,0.709,0.707]
# lr = [0.506,0.746,0.744]
# fred = [0.757,0.714,0.726]
# fred_dem = [0.894,0.72,0.824]
# hier = [0.693,0.691,0.719]
# hier_dem = [0.829,0.785,0.827]



# target = [0.749,0.749,0.701,0.722]
# lr = [0.748,0.749,0.749,0.722]
# fred= [0.726,0.749,0.752,0.752]
# fred_dem = [0.824,0.883,0.873,0.881]
# hier = [0.8,0.694,0.719,0.692]
# hier_dem = [0.827,0.816,0.85,0.838]


target = [0.707,0.707,0.7,0.749 ,0.701,0.699]
lr = [0.746,0.744,0.746,0.748,0.745,0.746]
fred = [0.716,0.76,0.742,0.726,0.76,0.866]
fred_dem = [0.744,0.742,0.873,0.824,0.879,0.867]
hier = [0.699,0.699,0.724,0.8,0.798,0.8]
hier_dem = [0.774,0.785,0.88,0.827,0.8,0.878] 



x = np.arange(6)


plt.plot(x,target)
plt.plot(x,lr)
plt.plot(x,fred)
plt.plot(x,fred_dem)
plt.plot(x,hier)
plt.plot(x,hier_dem)
plt.title("Huterite")
plt.xticks(np.arange(6), ('5','10','15', '20','25','30'))

plt.xlabel("Proportion of training instances")
plt.ylabel("AUC Scores")

plt.legend(['target','LR','FRED','FRED (demo)','Hier','Hier (demo)'],loc = 'lower right')
plt.show()
